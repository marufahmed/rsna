# %%
import os
import numpy as np
import cv2
import nibabel as nib
import pydicom
import pandas as pd
import multiprocessing

# Function to resize a 2D image to the desired size with interpolation
def resize_image(image, target_size=(128, 128)):
    return cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)

# Define default values for slice thickness and pixel spacing
default_slice_thickness = 1.0
default_pixel_spacing_x = 1.0
default_pixel_spacing_y = 1.0

# Create a 3D volume by dynamically sampling slices
def create_3d_volume_with_keyframes(images, target_size=(128, 128, 128), parquet_data=None):
    n_slices = len(images)
    
    keyframe_indices = np.linspace(0, n_slices - 1, target_size[2], dtype=int)
    
    selected_slices = []
    selected_filenames = []

    for idx in keyframe_indices:
        selected_slices.append(images[idx]["pixel_array"])
        selected_filenames.append(images[idx]["filename"])
    
    slice_thicknesses = []
    pixel_spacings = []
    for filename in selected_filenames:
        matching_row = parquet_data[parquet_data['path'] == filename]
        if not matching_row.empty:
            slice_thicknesses.append(matching_row['SliceThickness'].values[0])
            pixel_spacings.append([matching_row['PixelSpacingX'].values[0], matching_row['PixelSpacingY'].values[0]])
        else:
            slice_thicknesses.append(default_slice_thickness)
            pixel_spacings.append([default_pixel_spacing_x, default_pixel_spacing_y])
    
    resized_slices = [resize_image(slice_array, target_size[:2]) for slice_array in selected_slices]
    volume = np.stack(resized_slices, axis=-1)
    
    voxel_spacing = [
        pixel_spacings[0][0],
        pixel_spacings[0][1],
        slice_thicknesses[0]
    ]
    
    return volume, voxel_spacing, selected_filenames

# Function to load and sort DICOM files from a directory numerically
def load_and_sort_dicom_files(patient_dir):
    dicom_files = [os.path.join(root, file) for root, dirs, files in os.walk(patient_dir) for file in files if file.endswith('.dcm')]
    
    # Create a list to store DICOM images as dictionaries
    dicom_images = []
    
    for full_path in dicom_files:
        dicom_data = pydicom.dcmread(full_path)
        
        filename = f"{int(dicom_data.SeriesNumber)}_{int(dicom_data.InstanceNumber):04d}.nii.gz"
        pixel_array = dicom_data.pixel_array
        
        # Create a dictionary for each DICOM image
        dicom_image = {
            "filename": filename,
            "pixel_array": pixel_array,
        }
        
        dicom_images.append(dicom_image)
    
    # Sort the DICOM images by their slice positions
    dicom_images.sort(key=lambda x: x["filename"])
    
    return dicom_images

# Function to load Parquet metadata from a file
def load_parquet_metadata(parquet_file):
    return pd.read_parquet(parquet_file)

# Function to create the desired output directory structure
def create_output_directories(output_dir, patient_id, scan_id):
    patient_dir = os.path.join(output_dir, patient_id)
    scan_dir = os.path.join(patient_dir, scan_id)
    
    os.makedirs(scan_dir, exist_ok=True)
    
    return scan_dir

# Example usage for the input directory and Parquet file
input_dir = '/kaggle/input/rsna-2023-abdominal-trauma-detection/train_images'
output_dir = '/kaggle/working/output_directory'
parquet_file = '/kaggle/input/rsna-2023-abdominal-trauma-detection/train_dicom_tags.parquet'

# Specify X, Y, and Z dimensions for the 3D volume
x_size, y_size, z_size = 128, 128, 128

# Load Parquet metadata
print("Loading Parquet metadata...")
parquet_metadata = load_parquet_metadata(parquet_file)

# Traverse the entire input directory
for patient_id in os.listdir(input_dir):
    patient_dir = os.path.join(input_dir, patient_id)
    
    if os.path.isdir(patient_dir):
        for scan_id in os.listdir(patient_dir):
            scan_dir = os.path.join(patient_dir, scan_id)
            
            if os.path.isdir(scan_dir):
                print(f"Processing patient {patient_id}, scan {scan_id}...")
                
                # List all DICOM files in the current scan directory
                dicom_images = load_and_sort_dicom_files(scan_dir)
                
                if len(dicom_images) > 0:
                    print("Creating 3D volume...")
                    output_volume, voxel_spacing, selected_filenames = create_3d_volume_with_keyframes(
                        dicom_images, (x_size, y_size, z_size), parquet_data=parquet_metadata)
                    
                    # Create the output directory for the current scan
                    output_scan_dir = create_output_directories(output_dir, patient_id, scan_id)
                    
                    print("Saving the 3D volume...")
                    nifti_image = nib.Nifti1Image(output_volume, np.diag(voxel_spacing + [1.0]))
                    output_file = os.path.join(output_scan_dir, 'ct_scan.nii.gz')
                    nib.save(nifti_image, output_file)
                    
                    print(f"Combined and resampled image saved as '{output_file}'.")
                else:
                    print("No DICOM files found in the current scan directory.")
# Out:
# Loading Parquet metadata...
# Processing patient 26501, scan 22032...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/26501/22032/ct_scan.nii.gz'.
# Processing patient 26501, scan 31614...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/26501/31614/ct_scan.nii.gz'.
# Processing patient 32627, scan 51693...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/32627/51693/ct_scan.nii.gz'.
# Processing patient 44515, scan 12236...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/44515/12236/ct_scan.nii.gz'.
# Processing patient 44515, scan 2942...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/44515/2942/ct_scan.nii.gz'.
# Processing patient 33834, scan 17341...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/33834/17341/ct_scan.nii.gz'.
# Processing patient 43024, scan 8491...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/43024/8491/ct_scan.nii.gz'.
# Processing patient 43024, scan 37372...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/43024/37372/ct_scan.nii.gz'.
# Processing patient 29128, scan 62543...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/29128/62543/ct_scan.nii.gz'.
# Processing patient 29128, scan 47004...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/29128/47004/ct_scan.nii.gz'.
# Processing patient 32529, scan 1478...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/32529/1478/ct_scan.nii.gz'.
# Processing patient 32529, scan 40022...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/32529/40022/ct_scan.nii.gz'.
# Processing patient 63306, scan 61936...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/63306/61936/ct_scan.nii.gz'.
# Processing patient 57853, scan 43413...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/57853/43413/ct_scan.nii.gz'.
# Processing patient 57853, scan 55234...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/57853/55234/ct_scan.nii.gz'.
# Processing patient 23561, scan 19317...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/23561/19317/ct_scan.nii.gz'.
# Processing patient 61701, scan 63764...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/61701/63764/ct_scan.nii.gz'.
# Processing patient 61701, scan 64075...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/61701/64075/ct_scan.nii.gz'.
# Processing patient 26883, scan 57967...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/26883/57967/ct_scan.nii.gz'.
# Processing patient 35798, scan 62886...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/35798/62886/ct_scan.nii.gz'.
# Processing patient 35798, scan 56485...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/35798/56485/ct_scan.nii.gz'.
# Processing patient 57149, scan 27710...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/57149/27710/ct_scan.nii.gz'.
# Processing patient 10295, scan 10410...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/10295/10410/ct_scan.nii.gz'.
# Processing patient 1518, scan 19204...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/1518/19204/ct_scan.nii.gz'.
# Processing patient 26365, scan 22632...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/26365/22632/ct_scan.nii.gz'.
# Processing patient 55580, scan 41337...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/55580/41337/ct_scan.nii.gz'.
# Processing patient 59784, scan 32444...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/59784/32444/ct_scan.nii.gz'.
# Processing patient 1316, scan 5984...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/1316/5984/ct_scan.nii.gz'.
# Processing patient 1316, scan 43094...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/1316/43094/ct_scan.nii.gz'.
# Processing patient 54668, scan 4683...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/54668/4683/ct_scan.nii.gz'.
# Processing patient 39127, scan 1342...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/39127/1342/ct_scan.nii.gz'.
# Processing patient 39127, scan 24349...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/39127/24349/ct_scan.nii.gz'.
# Processing patient 61834, scan 51596...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/61834/51596/ct_scan.nii.gz'.
# Processing patient 61834, scan 47652...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/61834/47652/ct_scan.nii.gz'.
# Processing patient 54183, scan 33526...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory

# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/49780/16377/ct_scan.nii.gz'.
# Processing patient 24529, scan 41981...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/24529/41981/ct_scan.nii.gz'.
# Processing patient 24529, scan 3257...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/24529/3257/ct_scan.nii.gz'.
# Processing patient 51080, scan 48957...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/51080/48957/ct_scan.nii.gz'.
# Processing patient 19679, scan 7439...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/19679/7439/ct_scan.nii.gz'.
# Processing patient 19679, scan 7923...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/19679/7923/ct_scan.nii.gz'.
# Processing patient 24513, scan 60883...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/24513/60883/ct_scan.nii.gz'.
# Processing patient 24513, scan 17044...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/24513/17044/ct_scan.nii.gz'.
# Processing patient 7369, scan 54651...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/7369/54651/ct_scan.nii.gz'.
# Processing patient 7369, scan 19713...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/7369/19713/ct_scan.nii.gz'.
# Processing patient 26385, scan 31101...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/26385/31101/ct_scan.nii.gz'.
# Processing patient 26385, scan 15833...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/26385/15833/ct_scan.nii.gz'.
# Processing patient 59744, scan 2846...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/59744/2846/ct_scan.nii.gz'.
# Processing patient 3907, scan 10893...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/3907/10893/ct_scan.nii.gz'.
# Processing patient 3907, scan 5674...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/3907/5674/ct_scan.nii.gz'.
# Processing patient 37942, scan 63754...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/37942/63754/ct_scan.nii.gz'.
# Processing patient 57370, scan 19856...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/57370/19856/ct_scan.nii.gz'.
# Processing patient 57370, scan 49787...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/57370/49787/ct_scan.nii.gz'.
# Processing patient 28490, scan 30257...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/28490/30257/ct_scan.nii.gz'.
# Processing patient 13326, scan 29623...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/13326/29623/ct_scan.nii.gz'.
# Processing patient 13326, scan 32479...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/13326/32479/ct_scan.nii.gz'.
# Processing patient 47512, scan 49172...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/47512/49172/ct_scan.nii.gz'.
# Processing patient 16342, scan 8736...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/16342/8736/ct_scan.nii.gz'.
# Processing patient 16342, scan 28711...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/16342/28711/ct_scan.nii.gz'.
# Processing patient 27434, scan 19632...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/27434/19632/ct_scan.nii.gz'.
# Processing patient 27434, scan 1504...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/27434/1504/ct_scan.nii.gz'.
# Processing patient 44593, scan 5093...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/44593/5093/ct_scan.nii.gz'.
# Processing patient 25095, scan 55034...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/25095/55034/ct_scan.nii.gz'.
# Processing patient 53395, scan 42377...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/53395/42377/ct_scan.nii.gz'.
# Processing patient 19, scan 14374...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/19/14374/ct_scan.nii.gz'.
# Processing patient 12510, scan 33610...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/12510/33610/ct_scan.nii.gz'.
# Processing patient 12510, scan 18649...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/12510/18649/ct_scan.nii.gz'.
# Processing patient 21795, scan 48429...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/21795/48429/ct_scan.nii.gz'.
# Processing patient 29181, scan 28776...
# Creating 3D volume...
# Saving the 3D volume...
# Combined and resampled image saved as '/kaggle/working/output_directory/29181/28776/ct_scan.nii.gz'.
# Processing patient 30604, scan 51843...
# Creating 3D volume...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 120
#     118 if len(dicom_images) > 0:
#     119     print("Creating 3D volume...")
# --> 120     output_volume, voxel_spacing, selected_filenames = create_3d_volume_with_keyframes(
#     121         dicom_images, (x_size, y_size, z_size), parquet_data=parquet_metadata)
#     123     # Create the output directory for the current scan
#     124     output_scan_dir = create_output_directories(output_dir, patient_id, scan_id)
#
# Cell In[5], line 34, in create_3d_volume_with_keyframes(images, target_size, parquet_data)
#      32 pixel_spacings = []
#      33 for filename in selected_filenames:
# ---> 34     matching_row = parquet_data[parquet_data['path'] == filename]
#      35     if not matching_row.empty:
#      36         slice_thicknesses.append(matching_row['SliceThickness'].values[0])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:82, in comp_method_OBJECT_ARRAY(op, x, y)
#      80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
# ---> 82     result = libops.scalar_compare(x.ravel(), y, op)
#      83 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split

# Define the path to the root directory containing CT scan data
data_root = '/kaggle/input/rsna-2023-abdominal-trauma-detection/train_images'  # Update with the actual path

# Load the train.csv file
train_csv_path = '/kaggle/input/rsna-2023-abdominal-trauma-detection/train.csv'  # Update with the actual path
train_df = pd.read_csv(train_csv_path)

# Function to load CT scans and labels
def load_ct_scans_and_labels(data_root, train_df):
    ct_scans = []
    labels = []

    for _, row in train_df.iterrows():
        patient_id = str(row['patient_id'])

        # Define the path to the patient's directory
        patient_dir = os.path.join(data_root, patient_id)

        # Check if the patient's directory exists
        if not os.path.exists(patient_dir):
            print(f"Patient directory not found for patient {patient_id}")
            continue

        # Walk through all subdirectories under the patient's directory
        for subdir, _, files in os.walk(patient_dir):
            for file in files:
                if file.endswith('ct_scan.nii.gz'):
                    ct_scan_path = os.path.join(subdir, file)

                    try:
                        # Load the CT scan using nibabel
                        ct_scan = nib.load(ct_scan_path).get_fdata()
                        ct_scans.append(ct_scan)

                        # Extract labels from the train.csv file
                        label_columns = ['bowel_healthy', 'bowel_injury', 'extravasation_healthy', 'extravasation_injury',
                                         'kidney_healthy', 'kidney_low', 'kidney_high', 'liver_healthy', 'liver_low',
                                         'liver_high', 'spleen_healthy', 'spleen_low', 'spleen_high', 'any_injury']
                        labels.append(row[label_columns].values)

                    except Exception as e:
                        print(f"Error loading CT scan for patient {patient_id}: {e}")

    # Duplicate labels for all scans of the same patient
    all_labels = []
    for _ in ct_scans:
        all_labels.extend(labels)

    return np.array(ct_scans), np.array(all_labels)

# Load CT scans and labels
ct_scans, labels = load_ct_scans_and_labels(data_root, train_df)

# Define input shape based on your CT scan dimensions (e.g., 128x128x128x1 for a single-channel scan)
input_shape = (128, 128, 128, 1)

# Define the number of classes for multi-label classification
num_classes = len(train_df.columns) - 2  # Subtracting 2 for 'patient_id' and 'scan_id' columns

# Define training parameters
epochs = 50  # You can adjust the number of training epochs
batch_size = 16  # You can adjust the batch size based on your system's capacity

# Configure early stopping callback
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose 'val_loss' or another metric to monitor
    patience=5,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restore model weights from the epoch with the best value of the monitored metric
)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(ct_scans, labels, test_size=0.2, random_state=42)

# Define the CNN model
model = keras.Sequential([
    # Add 3D convolutional layers, pooling layers, and other layers as needed
    # Example:
    keras.layers.Conv3D(64, kernel_size=(3, 3, 3), activation='relu', input_shape=input_shape),
    keras.layers.MaxPooling3D(pool_size=(2, 2, 2)),
    # Add more layers as needed
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(num_classes, activation='sigmoid')  # Multi-label classification
])

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model on GPU
with tf.device('/device:GPU:0'):
    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[early_stopping])


# Evaluate the model
evaluation = model.evaluate(X_val, y_val)
print(f"Validation loss: {evaluation[0]}, Validation accuracy: {evaluation[1]}")

# Make predictions on new data
# predictions = model.predict(new_data)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 60
#      57     return np.array(ct_scans), np.array(all_labels)
#      59 # Load CT scans and labels
# ---> 60 ct_scans, labels = load_ct_scans_and_labels(data_root, train_df)
#      62 # Define input shape based on your CT scan dimensions (e.g., 128x128x128x1 for a single-channel scan)
#      63 input_shape = (128, 128, 128, 1)
#
# Cell In[1], line 33, in load_ct_scans_and_labels(data_root, train_df)
#      30     continue
#      32 # Walk through all subdirectories under the patient's directory
# ---> 33 for subdir, _, files in os.walk(patient_dir):
#      34     for file in files:
#      35         if file.endswith('ct_scan.nii.gz'):
#
# File /opt/conda/lib/python3.10/os.py:419, in _walk(top, topdown, onerror, followlinks)
#     414         # Issue #23605: os.path.islink() is used instead of caching
#     415         # entry.is_symlink() result during the loop on os.scandir() because
#     416         # the caller can replace the directory entry during the "yield"
#     417         # above.
#     418         if followlinks or not islink(new_path):
# --> 419             yield from _walk(new_path, topdown, onerror, followlinks)
#     420 else:
#     421     # Recurse into sub-directories
#     422     for new_path in walk_dirs:
#
# File /opt/conda/lib/python3.10/os.py:368, in _walk(top, topdown, onerror, followlinks)
#     366 try:
#     367     try:
# --> 368         entry = next(scandir_it)
#     369     except StopIteration:
#     370         break
#
# KeyboardInterrupt:
